# %% [markdown]
# # 삼차&사차 방정식

# %%
import sympy as sp
sp.init_printing()

# %%
x = sp.symbols('x')

expr1 = x ** 3 + 1
cal1 = sp.factor(expr)

display(cal)

expr2 = x ** 4 -10 * x **2 + 9
cal2 = sp.factor(expr2)

display(cal2)
# Out:
#         ⎛ 2        ⎞
# (x + 1)⋅⎝x  - x + 1⎠
# (x - 3)⋅(x - 1)⋅(x + 1)⋅(x + 3)
